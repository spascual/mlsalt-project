# %%
import numpy as np
import pandas as pd
import GPy
import time
import sys
import os
import pdb
import matplotlib.pyplot as plt

from context import aep
from context import load_data
from context import delete_blocks
from context import start_df
from context import save_df
from context import metrics
from thesis_work.plots import GP_figures
from thesis_work.plots import SGP_figures
from thesis_work.plots import DGP_figures

from baseline_models import full_GP_reg
from baseline_models import sparse_GP_reg
from aep_config import cont_optimization
from aep_config import aep_DGP_reg

default_dict = {'M': 50, 'hidden_size': [2], 
			'optimizer':'adam', 'max_it':100,
            'MB': 250, 'lr': 0.01, 'fixed_hyp': []}
os.getcwd()
# %matplotlib notebook

# %% [markdown]
# # Load data: normalise, delete blocks

# %%
path = 'data/dgp_samples/old/sample_3.txt'
X_train, y_train, X_test, y_test = load_data(path, N_train=1250, test=0.4, norm_out=False)
# X_test, y_test = delete_blocks(X_test, y_test,
#                                intervals=[2,4,8,9])
plt.figure()
plt.plot(X_test, y_test, '+')
plt.show()
# Out:
# Dataset size:  5000  Test size:  2000.0
# Training:  1250
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Sparse GP

# %%
model_sgp, df = sparse_GP_reg(X_train, y_train, X_test, y_test, M=75)
fig = SGP_figures(model_sgp).plot()
# Out:
# create SGP model and optimize ...
# Test MSE =0.011, NLL =-0.843
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # AEP Deep GPs

# %%
N_train = X_train.shape[0]
# ['zu_0', 'sf_0', 'ls_0', 'eta2_0', 'eta1_R_0']
config_dict = {'M': 75, 'hidden_size': [2], 
			'optimizer':'adam', 'max_it':600,
            'MB': 250, 'lr': 0.01, 'fixed_hyp': ['zu_0', 'sf_0', 'ls_0', 'eta2_0'],
            'init_type':'greedy'}

model, df, costs = aep_DGP_reg(X_train, y_train, X_test, y_test, 
				conf_dict= config_dict,
				return_cost=True)
fig0 = DGP_figures(model,conf_dict=config_dict).plot_cost(costs)
# Out:
# Create DGP model and optimize ...
# Optimise with fixed:  ['zu_0', 'sf_0', 'ls_0', 'eta2_0']
# SGP greedy initialisation
# Perform sparse GP regression
# sf_0
# sn
# ls_0
# eta2_0
# zu_0
# eta1_R_0
# iter 0 	 obj 1.612
# iter 50 	 obj 0.892
# iter 100 	 obj 0.510
# iter 150 	 obj -0.191
# iter 200 	 obj -0.441
# iter 250 	 obj -0.563
# iter 300 	 obj -0.638
# iter 350 	 obj -0.612
# iter 400 	 obj -0.610
# iter 450 	 obj -0.628
# iter 500 	 obj -0.631
# iter 550 	 obj -0.646
# Test MSE= 0.012, NLL= -0.782, SN= 0.104
# <img src="data:image/png;base64,..." width="640">

# %%
config_dict2 = {'M': 75, 'hidden_size': [2], 
			'optimizer':'adam', 'max_it':1000,
            'MB': 250, 'lr': 0.01, 'fixed_hyp': [],
            'init_type':'greedy'}
model, df = cont_optimization(model, X_test, y_test, conf_dict=config_dict2,
                              new_max_it=1000, return_cost=False)
# Out:
# iter 0 	 obj -0.623
# iter 50 	 obj -0.664

# %% [markdown]
# main_folder = 'scores/'
# save_df(main_folder, df, name=config_dict['init_type']+'-5')

# %% [markdown]
# ### Fitting plots

# %%
fig1 = DGP_figures(model, config_dict).plot()
fig2 = DGP_figures(model, config_dict).plot_sample()
# Out:
# <img src="data:image/png;base64,..." width="640">
# SGP greedy initialisation
# Perform sparse GP regression
# sf_0
# sn
# ls_0
# eta2_0
# zu_0
# eta1_R_0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Hidden Layer

# %%
fig3 = DGP_figures(model, conf_dict=config_dict).plot_in_h()
# Out:
# Default initialisation
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
fig4 = DGP_figures(model, conf_dict=config_dict).plot_hidden()
# Out:
# Default initialisation
# <img src="data:image/png;base64,..." width="640">

# %%
fig5 = DGP_figures(model, conf_dict=config_dict).plot_h_out()
# Out:
# Default initialisation
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Initialisations

# %%
fig6 = DGP_figures(model, conf_dict=config_dict).plot_init()
# Out:
# SGP greedy initialisation
# Perform sparse GP regression
# sf_0
# sn
# ls_0
# eta2_0
# zu_0
# eta1_R_0
# <img src="data:image/png;base64,..." width="640">

# %%
fig6 = DGP_figures(model, conf_dict=config_dict).plot_init()
# Out:
# SGP greedy initialisation
# Perform sparse GP regression
# sf_0
# sn
# ls_0
# eta2_0
# zu_0
# eta1_R_0
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Baseline models

# %%
model_gp, df = full_GP_reg(X_train, y_train, X_test, y_test)
fig = GP_figures(model_gp).plot()
# Out:
# create full GP model and optimize ...
# Test MSE =0.005, NLL =-1.267
# <img src="data:image/png;base64,..." width="640">

# %%
model_sgp = GPy.models.SparseGPRegression(X_train,y_train, kernel=GPy.kern.RBF(input_dim=1),num_inducing=50)
param = model_sgp.optimize('bfgs',messages=False)

# %%
zu = model_sgp.Z.values
sf = model_sgp.kern.variance.values
ls = model_sgp.kern.lengthscale.values
sn = model_sgp.likelihood.variance.values

# %%
def compute_kernel(lls, lsf, x, z):

    ls = np.exp(lls)
    sf = np.exp(lsf)

    if x.ndim == 1:
        x= x[ None, : ]

    if z.ndim == 1:
        z= z[ None, : ]

    r2 = cdist(x, z, 'seuclidean', V = ls)**2.0  
    k = sf * np.exp(-0.5*r2)
    return k
from scipy.spatial.distance import cdist
JITTER = 1e-5
M = 50
Dout = 1

Kuu = compute_kernel(2 * np.log(ls), 2 * np.log(sf), zu, zu)
# Kuu += np.diag(JITTER * np.ones((M, )))
Kuuinv = np.linalg.inv(Kuu)

# %%
print model_sgp.kern.K(zu)- Kuu
# Out:
# [[  1.00056757e-001   2.09137325e-251   2.58373358e-230 ...,
#     3.25734980e-003   6.12440952e-055   2.22580786e-124]
#  [  2.09137325e-251   1.00056757e-001   3.42721219e-002 ...,
#     1.95506991e-291   4.35820532e-074   4.58659559e-024]
#  [  2.58373358e-230   3.42721219e-002   1.00056757e-001 ...,
#     1.11381667e-268   6.01399075e-063   4.40795604e-018]
#  ...,
#  [  3.25734980e-003   1.95506991e-291   1.11381667e-268 ...,
#     1.00056757e-001   3.21079592e-074   7.02528480e-153]
#  [  6.12440952e-055   4.35820532e-074   6.01399075e-063 ...,
#     3.21079592e-074   1.00056757e-001   5.13846560e-016]
#  [  2.22580786e-124   4.58659559e-024   4.40795604e-018 ...,
#     7.02528480e-153   5.13846560e-016   1.00056757e-001]]

# %%
Kuu = compute_kernel(2 * ls, 2 * sf, zu, zu)
Kuu += np.diag(JITTER * np.ones((M, )))
Kuuinv = np.linalg.inv(Kuu)

eta1_R = np.zeros((Dout, M * (M + 1) / 2))
eta2 = np.zeros((Dout, M))
for d in range(Dout):
    mu = np.linspace(-1, 1, M).reshape((M, 1))
    # mu += 0.01 * np.random.randn(M, 1)
    alpha = 0.5 * np.random.rand(M)
    # alpha = 0.1 * np.random.rand(M) # worse init obj = 44.2
    alpha = sn1 * np.random.rand(M)
    Su = np.diag(alpha)
    
    Suinv = np.diag(1 / alpha)
    theta2 = np.dot(Suinv, mu)
    # theta2 = np.dot(Suinv + Kuuinv, mu)
    theta1 = Suinv
    

    R = np.linalg.cholesky(theta1).T
    triu_ind = np.triu_indices(M)
    diag_ind = np.diag_indices(M)
    R[diag_ind] = np.log(R[diag_ind])
    eta1_d = R[triu_ind].reshape((M * (M + 1) / 2,))
    eta2_d = theta2.reshape((M,))
    eta1_R[d, :] = eta1_d
    eta2[d, :] = eta2_d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-4d4ac62e972a> in <module>()
#      10     alpha = 0.5 * np.random.rand(M)
#      11     # alpha = 0.1 * np.random.rand(M) # worse init obj = 44.2
# ---> 12     alpha = sn1 * np.random.rand(M)
#      13     Su = np.diag(alpha)
#      14
#
# NameError: name 'sn1' is not defined

# %%
mu, Su = model_sgp.predict(zu, full_cov=True)
xx = np.linspace(0,10, 500).reshape(-1,1)
m, S = model_sgp.predict(xx)
Kuu = model_sgp.kern.K(zu)
Kuu += np.diag(1e-2* np.ones((M, )))
Kuuinv = np.linalg.inv(Kuu)
Suinv = np.linalg.inv(Su - np.diag(1e-1* np.ones((M, )))) 
theta1 = Suinv - Kuuinv + np.diag(1e-3* np.ones((M, )))
print np.min(np.linalg.eigvals(theta1))
np.linalg.cholesky(theta1).T
# Out:
# 2.53898512968
# array([[  7.44404435e+00,  -5.10264431e-13,  -4.33130118e-09, ...,
#           3.74356367e-02,   1.17746155e-08,  -6.63065221e-12],
#        [  0.00000000e+00,   7.00698153e+00,   4.72401406e-01, ...,
#          -4.21039471e-10,  -7.27691052e-05,  -9.40852192e-03],
#        [  0.00000000e+00,   0.00000000e+00,   7.11402422e+00, ...,
#           5.25042220e-11,   4.90605441e-06,   1.04484510e-03],
#        ...,
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           7.35007026e+00,  -2.39515823e-05,  -2.18202746e-07],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   7.46165582e+00,  -1.76264906e-02],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   7.14911639e+00]])

# %% [markdown]
# eta1_R

# %%
eta1_R.shape
# Out:
# (1, 1275)

# %%
model_dgp = aep.SDGPR(X_train, y_train, 50, hidden_sizes=[2], lik='Gaussian')
params0 = model_dgp.optimise(method='adam', maxiter=1)
# Out:
# Default initialisation
# iter 0 	 obj 41.159

# %%
for i in params0.keys():
    print i, params0[i].shape, params0[i]
# Out:
# zu_1 (50, 2) [[-1.001      -0.999     ]
#  [-0.96018367 -0.96018367]
#  [-0.91736735 -0.91936735]
#  [-0.87655102 -0.87855102]
#  [-0.83573469 -0.83773469]
#  [-0.79491837 -0.79691837]
#  [-0.75410204 -0.75610204]
#  [-0.71328571 -0.71528571]
#  [-0.67246939 -0.67446939]
#  [-0.63165306 -0.63365306]
#  [-0.59083674 -0.59283673]
#  [-0.55002041 -0.55002041]
#  [-0.51120408 -0.50920408]
#  [-0.47038776 -0.46838776]
#  [-0.42957143 -0.42757143]
#  [-0.3887551  -0.3867551 ]
#  [-0.34793878 -0.34593878]
#  [-0.30712245 -0.30512245]
#  [-0.26430612 -0.26430612]
#  [-0.2234898  -0.2234898 ]
#  [-0.18267347 -0.18467347]
#  [-0.14185714 -0.14385714]
#  [-0.10104082 -0.10304082]
#  [-0.06022449 -0.06222449]
#  [-0.01940816 -0.02140816]
#  [ 0.02140816  0.01940816]
#  [ 0.06222449  0.06022449]
#  [ 0.10304082  0.10104082]
#  [ 0.14385714  0.14185714]
#  [ 0.18467347  0.18267347]
#  [ 0.2254898   0.2234898 ]
#  [ 0.26630612  0.26430612]
#  [ 0.30712245  0.30512245]
#  [ 0.34793878  0.34593878]
#  [ 0.3887551   0.3867551 ]
#  [ 0.42957143  0.42757143]
#  [ 0.47038776  0.46838776]
#  [ 0.51120408  0.50920408]
#  [ 0.55202041  0.55002041]
#  [ 0.59283673  0.59083673]
#  [ 0.63365306  0.63165306]
#  [ 0.67446939  0.67246939]
#  [ 0.71528571  0.71328571]
#  [ 0.75610204  0.75410204]
#  [ 0.79691837  0.79491837]
#  [ 0.83773469  0.83573469]
#  [ 0.87855102  0.87655102]
#  [ 0.91936735  0.91736735]
#  [ 0.95818367  0.95818367]
#  [ 0.999       0.999     ]]
# zu_0 (50, 1) [[ 0.33013165]
#  [ 0.20208043]
#  [ 1.98629492]
#  [ 5.43286505]
#  [ 2.21922142]
#  [ 7.41046379]
#  [ 0.08874939]
#  [ 6.94444484]
#  [ 0.77097466]
#  [ 2.65806283]
#  [ 6.51084203]
#  [ 7.60964346]
#  [ 4.06262545]
#  [ 9.76168285]
#  [ 8.27831092]
#  [ 5.16763808]
#  [ 4.92672029]
#  [ 1.32597443]
#  [ 7.78996174]
#  [ 0.41773812]
#  [ 3.81477631]
#  [ 1.7808556 ]
#  [ 4.44757943]
#  [ 3.144008  ]
#  [ 1.21481966]
#  [ 2.50026717]
#  [ 5.80828668]
#  [ 8.95383193]
#  [ 1.60244058]
#  [ 9.35918852]
#  [ 2.35894398]
#  [ 7.14665906]
#  [ 0.51120488]
#  [ 1.05842377]
#  [ 8.00963202]
#  [ 2.8272214 ]
#  [ 1.48977813]
#  [ 7.27876825]
#  [ 0.89885994]
#  [ 3.35669522]
#  [ 3.5758845 ]
#  [ 1.89061379]
#  [ 4.63695965]
#  [ 0.63198046]
#  [ 2.99919928]
#  [ 6.73598051]
#  [ 4.26145418]
#  [ 6.18163305]
#  [ 2.06782673]
#  [ 8.59536082]]
# sf_0 (1,) [-0.69214718]
# sf_1 (1,) [ 0.001]
# sn () -4.60417018599
# ls_0 (1,) [ 0.37783652]
# ls_1 (2,) [ 0.0321092   0.00730891]
# eta2_1 (1, 50) [[ -2.61843588e+02  -7.51348664e+00  -2.39159264e+01  -2.60893809e+00
#    -2.34652413e+01  -5.06670310e+01  -1.73123463e+00  -2.53390230e+00
#    -1.52725496e+00  -2.89489007e+00  -1.48919333e+00  -4.01921142e+00
#    -1.15602833e+00  -7.78899856e+00  -1.36956369e+00  -3.86548589e+00
#    -4.67198287e+01  -7.36351507e-01  -1.09593460e+00  -1.31971858e+00
#    -4.02112123e-01  -1.19243704e+00  -5.79441182e-01  -5.26859812e-01
#    -8.02184353e-02   4.41356639e-02   4.19236244e-01   1.93994826e+00
#     3.08623256e-01   5.03193032e-01   1.00577683e+00   2.70452232e+00
#     6.48490426e-01   1.35362907e+00   1.82975921e+00   1.57122611e+00
#     1.45255656e+00   2.55989602e+00   1.91518151e+01   1.85179716e+00
#     7.18309441e+00   3.23901464e+00   2.45692360e+01   2.24615351e+00
#     3.42007328e+00   1.37341219e+01   9.07205440e+00   2.17584914e+00
#     4.59387207e+00   4.84987012e+00]]
# eta2_0 (2, 50) [[ -9.32386740e+00  -2.89252985e+00  -2.68445360e+00  -3.37065664e+00
#    -2.33494353e+00  -4.17983897e+00  -1.60980759e+00  -2.18203871e+00
#    -1.03628370e+01  -6.56238059e+00  -3.88895411e+00  -1.62541998e+00
#    -3.29134532e+00  -2.42867643e+00  -6.10485985e+00  -1.19729535e+00
#    -1.69923151e+00  -1.71651607e+00  -1.26431369e+00  -4.66929036e-01
#    -6.31192896e-01  -3.16459986e-01  -2.27593449e-01  -6.04006285e-01
#    -6.08462191e-02   6.31607290e-02   2.82749454e-01   3.38214640e-01
#     8.47902892e-01   4.53156765e-01   1.05397621e+00   6.43084229e-01
#     7.50025855e-01   1.37344766e+00   3.17104063e+00   1.86101661e+00
#     9.75957059e-01   2.10816949e+00   5.30825285e+00   4.57460188e+00
#     7.02396432e+00   5.67516930e+01   3.17331567e+00   1.39053154e+01
#     1.30116729e+01   5.97164690e+00   2.84460719e+00   3.20242763e+00
#     2.19030741e+00   5.12035933e+00]
#  [ -4.09535362e+01  -3.29891767e+00  -4.86659768e+00  -1.20741844e+01
#    -3.11935839e+00  -1.59252982e+00  -3.42355086e+01  -6.66525636e+00
#    -2.90696023e+00  -1.79860137e+01  -1.84968599e+00  -2.11846336e+00
#    -5.58274475e+00  -4.96074029e+00  -2.47393229e+00  -8.85195910e+00
#    -7.08176144e-01  -8.02662144e-01  -2.38999254e+00  -9.07461496e+00
#    -4.23148954e-01  -1.45495950e+00  -9.22396308e-01  -1.54496614e-01
#    -2.57707014e-01   8.91861214e-02   1.98685959e-01   1.31636347e+02
#     9.45858387e-01   7.01390129e-01   5.86016468e-01   7.45933404e-01
#     1.38818721e+00   2.28081587e+00   3.70726984e+00   3.98441056e+00
#     2.53235507e+01   7.28757928e+00   4.61948000e+00   1.24049477e+00
#     2.38262239e+00   2.75996588e+00   1.79269205e+00   3.92235907e+00
#     3.41747968e+00   3.30001545e+00   3.69760593e+00   1.94431846e+00
#     1.41651271e+02   4.13189325e+00]]
# eta1_R_1 (1, 1275) [[  2.78287176e+00   9.99999685e-04   9.99999903e-04 ...,   7.82089125e-01
#    -9.99999980e-04   7.88372857e-01]]
# eta1_R_0 (2, 1275) [[  1.11734237e+00   9.99999973e-04  -9.99999986e-04 ...,   4.14085525e-01
#     9.99999877e-04   8.15709949e-01]
#  [  1.85520687e+00  -9.99999981e-04   9.99999989e-04 ...,   2.49651692e+00
#    -9.99999980e-04   7.08246833e-01]]

# %%
params1 = model_dgp.optimise(method='adam', maxiter=100, reinit_hypers=False)
# Out:
# iter 0 	 obj 39.928
# iter 50 	 obj 7.400

# %%
for i in params1.keys():
    print i, params1[i].shape
# Out:
# zu_1 (50, 2)
# zu_0 (50, 1)
# sf_0 (1,)
# sf_1 (1,)
# sn ()
# ls_0 (1,)
# ls_1 (2,)
# eta2_1 (1, 50)
# eta2_0 (2, 50)
# eta1_R_1 (1, 1275)
# eta1_R_0 (2, 1275)

# %%
zu.shape
# Out:
# (50, 1)

# %%
sn.shape
# Out:
# (1,)
