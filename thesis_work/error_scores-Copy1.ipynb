# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from score_reading import load_data_frames
from score_reading import pivot_mean_std
from score_reading import plot_errors
import os
import seaborn
# %matplotlib notebook
seaborn.set_style("whitegrid")

# %%
for i in range(6): 
    print 'dataset %i' % (i+1)
    path = 'scores/dgp_samples_old/baseline'+ str(i+1)
    baseline = load_data_frames(path)
#     path = 'scores/greedy-'+ str(i+1)
#     greedy = load_data_frames(path)
#     path = 'scores/fixed_zu'+ str(i+1)
#     fix = load_data_frames(path)
    path = 'scores/dgp_samples_old/default'+str(i+1)
    default = load_data_frames(path)
    for metr in ['mse', 'nll']:
        plt.figure()
        plot_errors(baseline[0], metric=metr)
#         plot_errors(baseline[1]['25'], metric=metr)
        plot_errors(baseline[1]['35'], metric=metr)
#         plot_errors(greedy[2]['50'], metric=metr, init=True)
    #     plot_errors(fix[2]['50'], metric=metr, init=True)
        plot_errors(default[2]['25'], metric=metr, init=True)
        plot_errors(default[2]['35'], metric=metr, init=True)
        plt.title
        plt.show()
# Out:
# dataset 1
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# dataset 2
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# dataset 3
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# dataset 4
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# dataset 5
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# dataset 6
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]
# <img src="data:image/png;base64,..." width="800">
# [True]
# [True]

# %%
path = 'scores/dgp_samples_old/baseline*'
baseline = load_data_frames(path)
# path = 'scores/greedy-*'
# greedy = load_data_frames(path)
# path = 'scores/fixed_zu*'
# fix = load_data_frames(path)
path = 'scores/dgp_samples_old/default*'
default = load_data_frames(path)
for metr in ['mse', 'nll']:
    plt.figure()
    plot_errors(baseline[0], metric=metr)
#     plot_errors(baseline[1]['25'], metric=metr)
    plot_errors(baseline[1]['35'], metric=metr)
    
#     plot_errors(greedy[2]['50'], metric=metr, init=True)
#     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['25'], metric=metr, init=True)
    plot_errors(default[2]['35'], metric=metr, init=True)

    
    plt.title
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# [True]
# <img src="data:image/png;base64,..." width="800">
# [True]

# %%
path = 'scores/baseline1'
baseline = load_data_frames(path)
path = 'scores/greedy-1'
greedy = load_data_frames(path)
path = 'scores/fixed_zu1'
fix = load_data_frames(path)
path = 'scores/default1'
default = load_data_frames(path)
for metr in ['mse', 'nll']:
    plt.figure()
    plot_errors(baseline[0], metric=metr)
    plot_errors(baseline[1]['50'], metric=metr)
    plot_errors(greedy[2]['50'], metric=metr, init=True)
#     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['50'], metric=metr, init=True)
    plt.show()
# Out:
# ['greedy']
# ['greedy']

# %%
path = 'scores/baseline*'
baseline = load_data_frames(path)
path = 'scores/greedy-*'
greedy = load_data_frames(path)
path = 'scores/fixed_zu*'
fix = load_data_frames(path)
path = 'scores/default*'
default = load_data_frames(path)
for metr in ['mse', 'nll']:
    plt.figure()
    plot_errors(baseline[0], metric=metr)
    plot_errors(baseline[1]['75'], metric=metr)
    plot_errors(greedy[2]['75'], metric=metr, init=True)
    plot_errors(greedy[2]['50'], metric=metr, init=True)
#     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['50'], metric=metr, init=True)
    plt.show()
# Out:
# ['greedy']
# ['greedy']
# ['greedy']
# ['greedy']

# %%
path = 'scores/baseline*'
baseline = load_data_frames(path)
path = 'scores/greedy-*'
greedy = load_data_frames(path)
path = 'scores/fixed_zu*'
fix = load_data_frames(path)
path = 'scores/default*'
default = load_data_frames(path)
for metr in ['mse', 'nll']:
    plt.figure()
    plot_errors(baseline[0], metric=metr)
    plot_errors(baseline[1]['40'], metric=metr)
    plot_errors(greedy[2]['40'], metric=metr, init=True)
#     plot_errors(greedy[2]['50'], metric=metr, init=True)
#     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['50'], metric=metr, init=True)
    plt.show()
# Out:
# ['greedy']
# ['greedy']
