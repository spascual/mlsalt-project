# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from score_reading import load_data_frames
from score_reading import pivot_mean_std
from score_reading import plot_errors
import os
# import seaborn
# %matplotlib notebook

# %% [markdown]
# for i in range(5):
#     print 'dataset %i' % (i+1)
#     path = 'scores/baseline'+ str(i+1)
#     baseline = load_data_frames(path)
#     path = 'scores/greedy-'+ str(i+1)
#     greedy = load_data_frames(path)
#     path = 'scores/fixed_zu'+ str(i+1)
#     fix = load_data_frames(path)
#     path = 'scores/default'+str(i+1)
#     default = load_data_frames(path)
#     for metr in ['mse', 'nll']:
#         plt.figure()
#         plot_errors(baseline[0], metric=metr)
#         plot_errors(baseline[1]['50'], metric=metr)
# #         plot_errors(greedy[2]['50'], metric=metr, init=True)
#     #     plot_errors(fix[2]['50'], metric=metr, init=True)
#         plot_errors(default[2]['50'], metric=metr, init=True)
#         plt.title
#         plt.show()

# %%
df = pd.DataFrame()
for i in default[2].keys():
    df = pd.concat((df,default[2][i]),axis=0)
df = df[df.N_train == 1000]
df.pivot(index='M', columns='exp',values='mse')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0c0c878d8ab4> in <module>()
#       1 df = pd.DataFrame()
# ----> 2 for i in default[2].keys():
#       3     df = pd.concat((df,default[2][i]),axis=0)
#       4 df = df[df.N_train == 1000]
#       5 df.pivot(index='M', columns='exp',values='mse')
#
# NameError: name 'default' is not defined

# %%
path = 'scores/baseline*'
baseline = load_data_frames(path)
path = 'scores/greedy-*'
greedy = load_data_frames(path)
path = 'scores/fixed_zu*'
fix = load_data_frames(path)
path = 'scores/default*'
default = load_data_frames(path)
path = 'scores/long_short*'
long_short = load_data_frames(path)
path = 'scores/short_long*'
short_long = load_data_frames(path)
for metr in ['mse', 'nll']:
    plt.figure()
    plot_errors(baseline[0], metric=metr)
    plot_errors(baseline[1]['50'], metric=metr, init=True)

#     plot_errors(greedy[2]['50'], metric=metr, init=True)
#     plot_errors(short_long[2]['50'], metric=metr, init=True)
#     plot_errors(greedy[2]['30'], metric=metr, init=True)
    plot_errors(greedy[2]['40'], metric=metr, init=True)
    plot_errors(greedy[2]['50'], metric=metr, init=True)
    plot_errors(greedy[2]['75'], metric=metr, init=True)
#     plot_errors(long_short[2]['50'], metric=metr, init=True)
#     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['50'], metric=metr)
#     plot_errors(default[2]['60'], metric=metr)
    plt.grid()
    plt.xlim([450,1300])
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15),
          ncol=3, fancybox=True, shadow=True)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ['default']
# ['greedy']
# ['greedy']
# ['greedy']
# <img src="data:image/png;base64,..." width="640">
# ['default']
# ['greedy']
# ['greedy']
# ['greedy']

# %% [markdown]
# path = 'scores/baseline1'
# baseline = load_data_frames(path)
# path = 'scores/greedy-1'
# greedy = load_data_frames(path)
# path = 'scores/fixed_zu1'
# fix = load_data_frames(path)
# path = 'scores/default1'
# default = load_data_frames(path)
# for metr in ['mse', 'nll']:
#     plt.figure()
#     plot_errors(baseline[0], metric=metr)
#     plot_errors(baseline[1]['50'], metric=metr)
# #     plot_errors(greedy[2]['50'], metric=metr, init=True)
# #     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['50'], metric=metr, init=True)
#     plt.show()

# %%
path = 'scores/baseline*'
baseline = load_data_frames(path)
path = 'scores/greedy-*'
greedy = load_data_frames(path)
path = 'scores/fixed_zu*'
fix = load_data_frames(path)
path = 'scores/default*'
default = load_data_frames(path)
for metr in ['mse', 'nll']:
    plt.figure()
    plot_errors(baseline[0], metric=metr)
    plot_errors(baseline[1]['75'], metric=metr)
    plot_errors(greedy[2]['75'], metric=metr, init=True)
    plot_errors(greedy[2]['50'], metric=metr, init=True)
#     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['50'], metric=metr, init=True)
    plt.show()
# Out:
# <div id='91741f28-756a-454f-8d91-37bc466460ec'></div>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-ba088b880833> in <module>()
#      10     plt.figure()
#      11     plot_errors(baseline[0], metric=metr)
# ---> 12     plot_errors(baseline[1]['75'], metric=metr)
#      13     plot_errors(greedy[2]['75'], metric=metr, init=True)
#      14     plot_errors(greedy[2]['50'], metric=metr, init=True)
#
# KeyError: '75'

# %%
path = 'scores/baseline*'
baseline = load_data_frames(path)
path = 'scores/greedy-*'
greedy = load_data_frames(path)
path = 'scores/fixed_zu*'
fix = load_data_frames(path)
path = 'scores/default*'
default = load_data_frames(path)
for metr in ['mse', 'nll']:
    plt.figure()
    plot_errors(baseline[0], metric=metr)
    plot_errors(baseline[1]['40'], metric=metr)
    plot_errors(greedy[2]['40'], metric=metr, init=True)
#     plot_errors(greedy[2]['50'], metric=metr, init=True)
#     plot_errors(fix[2]['50'], metric=metr, init=True)
#     plot_errors(default[2]['50'], metric=metr, init=True)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ['greedy']
# <img src="data:image/png;base64,..." width="640">
# ['greedy']
